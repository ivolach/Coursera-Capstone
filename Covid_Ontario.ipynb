# %%
import urllib
import pandas as pd
from csv import DictReader

url = 'https://data.ontario.ca/api/3/action/datastore_search?resource_id=ed270bb8-340b-41f9-a7c6-e8ef587e6d11'  
fileobj = urllib.request.urlopen(url)
data = fileobj.read()

# open file in read mode
with open(data, 'r') as read_obj:
    # pass the file object to DictReader() to get the DictReader object
    dict_reader = DictReader(read_obj)
    # get a list of dictionaries from dct_reader
    list_of_dict = list(dict_reader)
    # print list of dict i.e. rows
    print(list_of_dict)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-09338cdd5123> in <module>
#       8
#       9 # open file in read mode
# ---> 10 with open(data, 'r') as read_obj:
#      11     # pass the file object to DictReader() to get the DictReader object
#      12     dict_reader = DictReader(read_obj)
#
# FileNotFoundError: [Errno 2] No such file or directory: b'{"help": "https://data.ontario.ca/api/3/action/help_show?name=datastore_search", "success": true, "result": {"include_total": true, "resource_id": "ed270bb8-340b-41f9-a7c6-e8ef587e6d11", "fields": [{"type": "int", "id": "_id"}, {"type": "timestamp", "id": "Reported Date"}, {"type": "numeric", "id": "Confirmed Negative"}, {"type": "numeric", "id": "Presumptive Negative"}, {"type": "numeric", "id": "Presumptive Positive"}, {"type": "numeric", "id": "Confirmed Positive"}, {"type": "numeric", "id": "Resolved"}, {"type": "numeric", "id": "Deaths"}, {"type": "numeric", "id": "Total Cases"}, {"type": "numeric", "id": "Total patients approved for testing as of Reporting Date"}, {"type": "numeric", "id": "Total tests completed in the last day"}, {"type": "numeric", "id": "Under Investigation"}, {"type": "numeric", "id": "Number of patients hospitalized with COVID-19"}, {"type": "numeric", "id": "Number of patients in ICU with COVID-19"}, {"type": "numeric", "id": "Number of patients in ICU on a ventilator with COVID-19"}, {"type": "numeric", "id": "Total Positive LTC Resident Cases"}, {"type": "numeric", "id": "Total Positive LTC HCW Cases"}, {"type": "numeric", "id": "Total LTC Resident Deaths"}, {"type": "numeric", "id": "Total LTC HCW Deaths"}], "records_format": "objects", "records": [{"_id":1,"Reported Date":"2020-01-26T00:00:00","Confirmed Negative":null,"Presumptive Negative":null,"Presumptive Positive":1,"Confirmed Positive":null,"Resolved":null,"Deaths":null,"Total Cases":null,"Total patients approved for testing as of Reporting Date":null,"Total tests completed in the last day":null,"Under Investigation":9,"Number of patients hospitalized with COVID-19":null,"Number of patients in ICU with COVID-19":null,"Number of patients in ICU on a ventilator with COVID-19":null,"Total Positive LTC Resident Cases":null,"Total Positive LTC HCW Cases":null,"Total LTC Resident Deaths":null,"Total LTC HCW Deaths":null},{"_id":2,"Reported Date":"2020-01-27T00:00:00","Confirmed Negative":null,"Presumptive Negative":null,"Presumptive Positive":2,"Confirmed Positive":null,"Resolved":null,"Deaths":null,"Total Cases":null,"Total patients approved for testing as of Reporting Date":null,"Total tests completed in the last day":null,"Under Investigation":19,"Number of patients hospitalized with COVID-19":null,"Number of patients in ICU with COVID-19":null,"Number of patients in ICU on a ventilator with COVID-19":null,"Total Positive LTC Resident Cases":null,"Total Positive LTC HCW Cases":null,"Total LTC Resident Deaths":null,"Total LTC HCW Deaths":null},{"_id":3,"Reported Date":"2020-01-28T00:00:00","Confirmed Negative":null,"Presumptive Negative":null,"Presumptive Positive":1,"Confirmed Positive":1,"Resolved":null,"Deaths":null,"Total Cases":1,"Total patients approved for testing as of Reporting Date":null,"Total tests completed in the last day":null,"Under Investigation":11,"Number of patients hospitalized with COVID-19":null,"Number of patients in ICU with COVID-19":null,"Number of patients in ICU on a ventilator with COVID-19":null,"Total Positive LTC Resident Cases":null,"Total Positive LTC HCW Cases":null,"Total LTC Resident Deaths":null,"Total LTC HCW Deaths":null},{"_id":4,"Reported Date":"2020-01-30T00:00:00","Confirmed Negative":null,"Presumptive Negative":null,"Presumptive Positive":0,"Confirmed Positive":2,"Resolved":null,"Deaths":null,"Total Cases":2,"Total patients approved for testing as of Reporting Date":null,"Total tests completed in the last day":null,"Under Investigation":27,"Number of patients hospitalized with COVID-19":null,"Number of patients in ICU with COVID-19":null,"Number of patients in ICU on a ventilator with COVID-19":null,"Total Positive LTC Resident Cases":null,"Total Positive LTC HCW Cases":null,"Total LTC Resident Deaths":null,"Total LTC HCW Deaths":null},{"_id":5,"Reported Date":"2020-01-31T00:00:00","Confirmed Negative":null,"Presumptive Negative":null,"Pres ...
